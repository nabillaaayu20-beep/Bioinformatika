# %% [markdown]
# <a href="https://colab.research.google.com/github/nabillaaayu20-beep/Bioinformatika/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=input ()
print (x+"1")
# Out:
# 5
# 51

# %%
print ("A","B",sep="-")
# Out:
# A-B

# %%
nama="Alya"
print(f"Halo,{nama}!")
# Out:
# Halo,Alya!

# %%
print ("A","B")
# Out:
# A B

# %%
x=7
y=3
print (x%y)
# Out:
# 1

# %%
x=input()
print(x+"1")
# Out:
# 5
# 51

# %%
print("A","B", sep="-")
print("C")
# Out:
# A-B
# C

# %%
print ("A",end="-")
print("B","C",sep="*")
# Out:
# A-B*C

# %%
x = int(input())
y = int(input())
hasil = x / y + 1
print(f"{hasil:.1f}")
# Out:
# 2
# 2
# 2.0
